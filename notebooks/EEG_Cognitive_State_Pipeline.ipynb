# %% [markdown]
# # EEG Cognitive State ML Pipeline
# Upload/unzip this project in Colab, then run the cells below.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Full real dataset run
# This downloads about 175 MB of EEG data and runs the full pipeline.

# %%
# !python run_pipeline.py --download --data_dir data/raw/eegmat --output_dir outputs --window_seconds 4 --overlap 0.5 --n_boot 500

# %% [markdown]
# ## Inspect outputs

# %%
import pandas as pd
pd.read_csv('outputs/models/metrics_holdout.csv')

# %%
pd.read_csv('outputs/statistics/top_significant_features.csv').head(20)
